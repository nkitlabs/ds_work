# %%
import os

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split

pd.set_option('display.float_format', lambda x: '{:.3f}'.format(x))
pd.set_option('display.max_columns', 500)

INPUT_FOLDER = r'D:\Users\S89780\Desktop\kzaki\python\ml\input\house-prices-advanced-regression-techniques'

# %% [markdown]
# # Input

# %%
price_data = pd.read_csv(os.path.join(INPUT_FOLDER, 'train.csv'))
price_train, price_test = train_test_split(price_data, test_size=0.2)
# price_test = pd.read_csv(os.path.join(INPUT_FOLDER, 'test.csv'))

# %%
price_train.head()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 900    901          20       RL          nan     7340   Pave   NaN      IR1
# 29      30          30       RM       60.000     6324   Pave   NaN      IR1
# 672    673          20       RL          nan    11250   Pave   NaN      IR1
# 1058  1059          60       RL       96.000    11308   Pave   NaN      IR1
# 1067  1068          60       RL       80.000     9760   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 900          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 29           Lvl    AllPub    Inside       Gtl      BrkSide      Feedr
# 672          Lvl    AllPub    Inside       Gtl      Veenker       Norm
# 1058         Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 1067         Lvl    AllPub    Inside       Mod        NAmes       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
price_test.head()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 22      23          20       RL       75.000     9742   Pave   NaN      Reg
# 646    647          20       RL       60.000     7200   Pave   NaN      Reg
# 1080  1081          20       RL       80.000    11040   Pave   NaN      Reg
# 998    999          30       RM       60.000     9786   Pave   NaN      Reg
# 870    871          20       RL       60.000     6600   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 22           Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 646          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 1080         Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 998          Lvl    AllPub    Inside       Gtl       IDOTRR       Norm
# 870          Lvl    AllPub    Inside       Gtl        NAmes       PosN
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# # Data Manipulation

# %%
def transform_log(df, cols, suffix_name='_lg'):
    _df = df.copy()
    for col in cols:
        _df[col+suffix_name] = _df[col].apply(np.log1p)
    return _df

def check_missing_data(df):
    data_na = (df.isnull().sum() / len(df)) * 100
    data_na = data_na.drop(data_na[data_na == 0].index).sort_values(ascending=False)[:30]
    missing_data = pd.DataFrame({'Missing Ratio' :data_na})
    if len(missing_data) == 0:
        print("No missing data")
    else:
        print(missing_data.head(10))

def get_homogeneous_columns(df, threshold=90.0):
    cols = []
    for c in df.columns:
        vc = df[c].value_counts()
        ratio = vc.to_list()[0]/len(df) * 100
        if ratio > threshold:
            cols.append(c)
    return cols

# %%
check_missing_data(price_train)
# Out:
#               Missing Ratio
# PoolQC               99.486
# MiscFeature          95.976
# Alley                93.750
# Fence                79.795
# FireplaceQu          47.517
# LotFrontage          17.209
# GarageYrBlt           5.736
# GarageType            5.736
# GarageFinish          5.736
# GarageQual            5.736

# %%
price_train = transform_log(price_train, ['SalePrice'])
fillna_mapping = {
    'LotFrontage': price_train["LotFrontage"].median(),
    'MasVnrType': 'None',
    'MasVnrArea': 0,
    'Electrical': 'SBrkr',
    'GarageType': 'None',
    'GarageFinish': 'None',
    'GarageQual': 'None',
    'GarageCond': 'None',
    'GarageYrBlt': 0,
    'GarageArea': 0,
    'GarageCars': 0,
    'BsmtQual': 'None',
    'BsmtCond': 'None',
    'BsmtExposure': 'None',
    'BsmtFinType1': 'None',
    'BsmtFinType2': 'None',
    'BsmtFinSF1': 0,
    'BsmtFinSF2': 0,
    'BsmtUnfSF': 0,
    'TotalBsmtSF': 0,
    'BsmtFullBath': 0,
    'BsmtHalfBath': 0,
}

drop_cols = list(set(['Id', 'SalePrice', 'PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu']) | set(get_homogeneous_columns(price_train)))

for k, v in fillna_mapping.items():
    price_train[k] = price_train[k].fillna(v)
price_train = price_train.drop(columns=drop_cols)

# %%
categorical_column = ['MSZoning', 'LotShape', 'LandContour', 
                      'LotConfig', 'Neighborhood', 'Condition1', 'BldgType', 'HouseStyle', 
                      'OverallQual', 'OverallCond', 'RoofStyle', 'Exterior1st', 'Exterior2nd', 
                      'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 
                      'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'HeatingQC', 'KitchenQual', 
                      'GarageType', 'GarageFinish', 'GarageQual', 'MoSold', 'SaleType', 'SaleCondition']

# %%
price_train = pd.get_dummies(price_train, columns=categorical_column, drop_first=True)

# %%
price_train.head()
# Out:
#       MSSubClass  LotFrontage  LotArea  YearBuilt  YearRemodAdd  MasVnrArea  \
# 900           20       70.000     7340       1971          1971       0.000
# 29            30       60.000     6324       1927          1950       0.000
# 672           20       70.000    11250       1977          1977       0.000
# 1058          60       96.000    11308       2008          2008     154.000
# 1067          60       80.000     9760       1964          1964     360.000
#
#       BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF  2ndFlrSF  \
# 900          322           0        536          858       858         0
# 29             0           0        520          520       520         0
# 672          767           0        441         1208      1208         0
# 1058         936           0        168         1104      1130      1054
# 1067         674         106          0          780       798       813
#
# ...

# %% [markdown]
# # Train model

# %%
y_train = price_train['SalePrice_lg']
X_train = price_train.drop(columns='SalePrice_lg')

# %%
from sklearn.linear_model import ElasticNet, Lasso,  BayesianRidge, LassoLarsIC
from sklearn.ensemble import RandomForestRegressor,  GradientBoostingRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error
import xgboost as xgb
import lightgbm as lgb

# %%
lasso = make_pipeline(RobustScaler(), Lasso(alpha =0.0005, random_state=1))

ENet = make_pipeline(RobustScaler(), ElasticNet(alpha=0.0005, l1_ratio=.9, random_state=3))

KRR = KernelRidge(alpha=0.6, kernel='polynomial', degree=2, coef0=2.5)

GBoost = GradientBoostingRegressor(n_estimators=3000, learning_rate=0.05,
                                   max_depth=4, max_features='sqrt',
                                   min_samples_leaf=15, min_samples_split=10, 
                                   loss='huber', random_state =5)

model_xgb = xgb.XGBRegressor(colsample_bytree=0.4603, gamma=0.0468, 
                             learning_rate=0.05, max_depth=3, 
                             min_child_weight=1.7817, n_estimators=2200,
                             reg_alpha=0.4640, reg_lambda=0.8571,
                             subsample=0.5213, silent=1,
                             random_state =7, nthread = -1)

model_lgb = lgb.LGBMRegressor(objective='regression',num_leaves=5,
                              learning_rate=0.05, n_estimators=720,
                              max_bin = 55, bagging_fraction = 0.8,
                              bagging_freq = 5, feature_fraction = 0.2319,
                              feature_fraction_seed=9, bagging_seed=9,
                              min_data_in_leaf =6, min_sum_hessian_in_leaf = 11)

# %%
def rmse_cv(model, X, y, n_folds=5):
    rmse= np.sqrt(-cross_val_score(model, X.values, y, scoring="neg_mean_squared_error", cv = n_folds))
    return(rmse)

# %%
import warnings
warnings.filterwarnings('ignore')

models = [('Lasso', lasso), ('ElasticNet', ENet), ('Ridge', KRR), 
          ('GBoostReg', GBoost), ('XGBoostReg', model_xgb), ('LGBMReg', model_lgb)]
for word, model in models:
    score = rmse_cv(model, X_train, y_train)
    print("{} score: {:.4f} ({:.4f})\n".format(word, score.mean(), score.std()))
# Out:
# Lasso score: 0.1442 (0.0232)
#
# ElasticNet score: 0.1443 (0.0229)
#
# Ridge score: 0.3851 (0.0717)
#
# GBoostReg score: 0.1303 (0.0127)
#
# XGBoostReg score: 0.1339 (0.0089)
#
# LGBMReg score: 0.1296 (0.0080)

# %%
# new_df = pd.get_dummies(new_data)
# # handle unknow by using .reindex and .fillna()
# new_df = new_df.reindex(columns=price_train.columns).fillna(0)
